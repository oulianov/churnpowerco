# %% [markdown]
# # PowerCo Business & Data Science case
#
# ## Introduction
#
# The data for this case study was provided with the courtesy of BCG Gamma during one of their workshop at HEC Paris. Customer's data was fully anonymized.
#
# We study client's data from an energy company. **The goal is to predict churn, and then propose a solution to avoid it.**
#
# In other words : Which clients are expected to leave the company ? How to prevent them from doing so ? How much will it cost us ?
#
# In this notebook,
#
# 1. We import, format and clean company's raw client data.
# 2. We predict churn using two machine learning techniques : **Random Forests and Extreme Gradient Boosting.** We compare their performance on relevant metrics.
# 3. We propose a way to avoid churn : offering a discount, set as to maximize company's overall profit.

# %% [markdown]
# ## 1. Data preprocessing
#
# The data was provided by PowerCo as it was extracted from their databases.

# %%
import pandas as pd
import numpy as np

# %%
# Importing client's data. Those were anonymized.  
pricing_df = pd.read_csv('data/Pricing data.csv')
energy_df = pd.read_csv('data/Energy usage data.csv')
finance_df = pd.read_csv('data/Finance data.csv')
crm_df = pd.read_csv('data/CRM data.csv')
sales_channel_df = pd.read_csv('data/Sales channel data.csv')
forecast_df = pd.read_csv('data/Forecast data.csv')

# %% [markdown]
# ### 1.a Preprocessing of pricing data
#
# Energy prices depends on a lot of factor, from who's the client, to the date of the month. The dataset `pricing_df` contains the daily pricing for energy of the last 12 days for each client.
#
# First, we need to unstack the columns. This is how the client stores data, but not how we need it to be.
#
# Then, we need to fill missing values. Indeed, some companies have only 10 days of pricing data instead of 12. We do so using *forward fill*.

# %%
#Pricing_df preprocessing : custom functions we'll use. 

def sample_df_by_id(df, size=100, by_id='id'):
    """Samples (size) items in column (by_id) of (df),
    then returns all the items of (df) with these (by_id)"""
    # This function was useful during development to avoid testing the 
    # preprocessing each time on the whole dataset. 
    sample_id = pd.Series(df[by_id].unique()).sample(size)
    sample_df = df[df[by_id].isin(sample_id)]
    return sample_df

def preprocess_price(df, new_row='id', new_column='price_date'):
    """Custom preprocessing to unstack, reindex and flatten columns, 
    and to propagate missing data."""
    others_s = pricing_df.columns.tolist()
    #To unstack columns, we build a pivot table. 
    df = df.pivot_table(values=others_s, index=new_row, columns=new_column, aggfunc=(lambda x: x))
    df = df.reset_index()
    df.columns = df.columns.to_flat_index()
    #Filling NA values with backfill, from left to right
    df = df.fillna(method='ffill') #.fillna(0)
    return df

# %%
#Preprocessing prices. Lengthy process due to filling NA values line by line. 

# sample = sample_df_by_id(proc_pricing_df)
# preprocess_sales(sample)
proc_pricing_df = preprocess_price(pricing_df)
proc_pricing_df.shape
# Out:
# (16094, 73)

# %% [markdown]
# ### 1.b Preprocessing of Sales Channel data
#
# This additionnal dataset contains information about client's activity (exact labelling was anonymized).
#
# Thus, this data is categorical and needs to be transformed.

# %%
def preprocess_sales(df):
    # We replace the encoding (t, f) by (1, 0)
    df['also_gas_client'].replace({'t': 1, 'f': 0}, inplace=True)
    # We use get_dummies to encode categorical data. 
    cols = list(sales_channel_df)
    cols.remove('id')
    cols.remove('also_gas_client')
    df = pd.get_dummies(df, columns=cols, dummy_na=True)
    return df

#sample = sample_df_by_id(sales_channel_df.copy())
#preprocess_sales(sample)
proc_sales_channel_df = sales_channel_df.copy()
proc_sales_channel_df = preprocess_sales(proc_sales_channel_df)
proc_sales_channel_df.shape
# Out:
# (28898, 437)

# %% [markdown]
# ### 1.c Merging all the datasets
#
# The other datasets are quite "data science ready" and require minimal preprocessing.
#
# We merge all the datasets into one big single datasets that we'll use for training our models.

# %%
#Merging datasets

proc_pricing_df = proc_pricing_df.rename(columns={('id', ''): 'id'})
merged_df = proc_pricing_df.merge(energy_df, on="id", how="left")
merged_df = merged_df.merge(finance_df, on="id", how="left")
merged_df = merged_df.merge(crm_df, on="id", how="left")

# This last dataset has a lot of missing values in some columns. We remove these columns. 
#forecas_df = forecast_df.drop(['forecast_ele_bill_next_01m', 
#                               'forecast_ele_bill_next_calyear',
#                               'forecast_ele_bill_next_12m',
#                               'forecast_consumption_ele_next_01m'], axis=1)

#merged_df = merged_df.merge(forecast_df)
merged_df = merged_df.merge(proc_sales_channel_df)

for c in merged_df.columns:
    if "Unnamed" in c:
        merged_df = merged_df.drop(c, 1)

merged_df
# Out:
#                                      id  (price_p1_fix, 2015-01-01)  \
# 0      0002203ffbb812588b632b9e628cc38d                   40.565969
# 1      0004351ebdd665e6ee664792efc4fd13                   44.266931
# 2      0010bcc39e42b3c2131ed2ce55246e3c                   44.444710
# 3      0010ee3855fdea87602a5b7aba8e42de                   40.565969
# 4      00114d74e963e47177db89bc70108537                   44.266931
# ...                                 ...                         ...
# 16087  ffef185810e44254c3a4c6395e6b4d8a                   41.063970
# 16088  fffac626da707b1b5ab11e8431a4d0a2                   44.266931
# 16089  fffc0cacd305dd51f316424bbb08d1bd                   41.063970
# 16090  fffe4f5646aa39c7f97f95ae2679ce64                   40.565969
# 16091  ffff7fa066f1fb305ae285bb03bf325a                   40.565969
#
#        (price_p1_fix, 2015-02-01)  (price_p1_fix, 2015-03-01)  \
# 0                       40.565969                   40.728885
# 1                       44.266931                   44.266931
# 2                       44.444710                   44.444710
# 3                       40.565969                   40.565969
# 4                       44.266931                   44.266931
# ...                           ...                         ...
# 16087                   41.063970                   41.063970
# 16088                   44.266931                   44.266931
# 16089                   41.063970                   41.063970
# 16090                   40.565969                   40.565969
# 16091                   40.565969                   40.565969
#
#        (price_p1_fix, 2015-04-01)  (price_p1_fix, 2015-05-01)  \
# 0                       40.728885                   40.728885
# 1                       44.266931                   44.444710
# 2                       44.444710                   44.444710
# 3                       40.565969                   40.565969
# 4                       44.266931                   44.266930
# ...                           ...                         ...
# 16087                   41.063970                   41.063970
# 16088                   44.266931                   44.266931
# 16089                   41.063970                   41.063970
# 16090                   40.565969                   40.565969
# 16091                   40.565969                   40.565969
#
#        (price_p1_fix, 2015-06-01)  (price_p1_fix, 2015-07-01)  \
# 0                       40.728885                   40.728885
# 1                       44.444710                   44.444710
# 2                       45.944710                   45.944710
# 3                       40.565973                   40.728885
# 4                       44.266930                   44.266930
# ...                           ...                         ...
# 16087                   41.063969                   40.728885
# 16088                   44.266930                   44.266930
# 16089                   41.228885                   41.228885
# 16090                   40.565973                   40.565973
# 16091                   40.565973                   40.728885
#
#        (price_p1_fix, 2015-08-01)  (price_p1_fix, 2015-09-01)  ...  \
# 0                       40.728885                   40.728885  ...
# 1                       44.444710                   44.444710  ...
# 2                       45.944710                   45.944710  ...
# 3                       40.728885                   40.728885  ...
# 4                       44.266930                   44.266930  ...
# ...                           ...                         ...  ...
# 16087                   40.728885                   40.728885  ...
# 16088                   44.266930                   44.266930  ...
# 16089                   41.228885                   41.228885  ...
# 16090                   40.565973                   40.565973  ...
# 16091                   40.728885                   40.728885  ...
#
#        company_activity_category_nan  \
# 0                                  1
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 16087                              0
# 16088                              1
# 16089                              0
# 16090                              1
# 16091                              1
#
#        customer_signup_campaign_ele_discount_nan  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 16087                                          1
# 16088                                          1
# 16089                                          1
# 16090                                          1
# 16091                                          1
#
#        customer_signup_campaign_sales_channel_epumfxlbckeskwekxbiuasklxalciiuu  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16087                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_ewpakwlliwisiwduibdlfmalxowmwpci  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      1
# ...                                                  ...
# 16087                                                  0
# 16088                                                  1
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_fixdbufsefwooaasfcxdxadsiekoceaa  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16087                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_foosdfpfkusacimwkcsosbicdxkicaua  \
# 0                                                      1
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16087                                                  1
# 16088                                                  0
# 16089                                                  1
# 16090                                                  0
# 16091                                                  1
#
#        customer_signup_campaign_sales_channel_lmkebamcaaclubfxadlmueccxoimlema  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      1
# 4                                                      0
# ...                                                  ...
# 16087                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_sddiedcslfslkckwlfkdpoeeailfpeds  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16087                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_usilxuppasemubllopkaafesmlibmsdf  \
# 0                                                      0
# 1                                                      0
# 2                                                      1
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16087                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_nan
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 16087                                           0
# 16088                                           0
# 16089                                           0
# 16090                                           1
# 16091                                           0
#
# [16092 rows x 523 columns]

# %% [markdown]
# Lastly, during training and data exploration, incoherent values were found :
#
# - negative energy consumption
# - strings were numbers were supposed to be found
#
# We remove the rows were such errors were found.

# %%
#Cleaning weird values

cleaned_df = merged_df[merged_df["obs_consumption_ele_last_12m"]>=0]
cleaned_df = cleaned_df[cleaned_df["obs_consumption_gas_last_12m"]>=0]
cleaned_df = cleaned_df[cleaned_df["obs_consumption_ele_last_01m"]>=0]

#We have some funky values in these columns. We replace them by na. 
cols = [('price_p1_fix', '2015-01-01'), ('price_p1_fix', '2015-02-01'), ('price_p1_fix', '2015-03-01'), 
     ('price_p1_fix', '2015-04-01'), ('price_p1_fix', '2015-05-01')]
cleaned_df[cols] = cleaned_df[cols].replace(regex='.*[a-zA-Z]+.*', value=np.nan)

cleaned_df = cleaned_df.dropna()
cleaned_df
# Out:
#                                      id  (price_p1_fix, 2015-01-01)  \
# 0      0002203ffbb812588b632b9e628cc38d                   40.565969
# 1      0004351ebdd665e6ee664792efc4fd13                   44.266931
# 2      0010bcc39e42b3c2131ed2ce55246e3c                   44.444710
# 3      0010ee3855fdea87602a5b7aba8e42de                   40.565969
# 4      00114d74e963e47177db89bc70108537                   44.266931
# ...                                 ...                         ...
# 16086  ffebf6a979dd0b17a41076df1057e733                   40.565969
# 16088  fffac626da707b1b5ab11e8431a4d0a2                   44.266931
# 16089  fffc0cacd305dd51f316424bbb08d1bd                   41.063970
# 16090  fffe4f5646aa39c7f97f95ae2679ce64                   40.565969
# 16091  ffff7fa066f1fb305ae285bb03bf325a                   40.565969
#
#        (price_p1_fix, 2015-02-01)  (price_p1_fix, 2015-03-01)  \
# 0                       40.565969                   40.728885
# 1                       44.266931                   44.266931
# 2                       44.444710                   44.444710
# 3                       40.565969                   40.565969
# 4                       44.266931                   44.266931
# ...                           ...                         ...
# 16086                   40.565969                   40.565969
# 16088                   44.266931                   44.266931
# 16089                   41.063970                   41.063970
# 16090                   40.565969                   40.565969
# 16091                   40.565969                   40.565969
#
#        (price_p1_fix, 2015-04-01)  (price_p1_fix, 2015-05-01)  \
# 0                       40.728885                   40.728885
# 1                       44.266931                   44.444710
# 2                       44.444710                   44.444710
# 3                       40.565969                   40.565969
# 4                       44.266931                   44.266930
# ...                           ...                         ...
# 16086                   40.565969                   40.565969
# 16088                   44.266931                   44.266931
# 16089                   41.063970                   41.063970
# 16090                   40.565969                   40.565969
# 16091                   40.565969                   40.565969
#
#        (price_p1_fix, 2015-06-01)  (price_p1_fix, 2015-07-01)  \
# 0                       40.728885                   40.728885
# 1                       44.444710                   44.444710
# 2                       45.944710                   45.944710
# 3                       40.565973                   40.728885
# 4                       44.266930                   44.266930
# ...                           ...                         ...
# 16086                   40.565973                   40.565973
# 16088                   44.266930                   44.266930
# 16089                   41.228885                   41.228885
# 16090                   40.565973                   40.565973
# 16091                   40.565973                   40.728885
#
#        (price_p1_fix, 2015-08-01)  (price_p1_fix, 2015-09-01)  ...  \
# 0                       40.728885                   40.728885  ...
# 1                       44.444710                   44.444710  ...
# 2                       45.944710                   45.944710  ...
# 3                       40.728885                   40.728885  ...
# 4                       44.266930                   44.266930  ...
# ...                           ...                         ...  ...
# 16086                   40.565973                   40.565973  ...
# 16088                   44.266930                   44.266930  ...
# 16089                   41.228885                   41.228885  ...
# 16090                   40.565973                   40.565973  ...
# 16091                   40.728885                   40.728885  ...
#
#        company_activity_category_nan  \
# 0                                  1
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 16086                              0
# 16088                              1
# 16089                              0
# 16090                              1
# 16091                              1
#
#        customer_signup_campaign_ele_discount_nan  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 16086                                          1
# 16088                                          1
# 16089                                          1
# 16090                                          1
# 16091                                          1
#
#        customer_signup_campaign_sales_channel_epumfxlbckeskwekxbiuasklxalciiuu  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16086                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_ewpakwlliwisiwduibdlfmalxowmwpci  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      1
# ...                                                  ...
# 16086                                                  0
# 16088                                                  1
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_fixdbufsefwooaasfcxdxadsiekoceaa  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16086                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_foosdfpfkusacimwkcsosbicdxkicaua  \
# 0                                                      1
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16086                                                  0
# 16088                                                  0
# 16089                                                  1
# 16090                                                  0
# 16091                                                  1
#
#        customer_signup_campaign_sales_channel_lmkebamcaaclubfxadlmueccxoimlema  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      1
# 4                                                      0
# ...                                                  ...
# 16086                                                  1
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_sddiedcslfslkckwlfkdpoeeailfpeds  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16086                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_usilxuppasemubllopkaafesmlibmsdf  \
# 0                                                      0
# 1                                                      0
# 2                                                      1
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 16086                                                  0
# 16088                                                  0
# 16089                                                  0
# 16090                                                  0
# 16091                                                  0
#
#        customer_signup_campaign_sales_channel_nan
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 16086                                           0
# 16088                                           0
# 16089                                           0
# 16090                                           1
# 16091                                           0
#
# [15813 rows x 523 columns]

# %% [markdown]
# Finally, build the matrices we'll use.

# %%
from sklearn.preprocessing import StandardScaler

#Building X and y matrices
to_predict = 'target_churned'
features = list(cleaned_df.columns)
features.remove(to_predict)
features.remove('id')

X = np.array(cleaned_df[features])
y = np.array(cleaned_df[to_predict]) 

# We build sampled matrices for quick visualization
sampled_df = sample_df_by_id(cleaned_df, 1000)
X_sampled = np.array(sampled_df[features])
y_sampled = np.array(sampled_df[to_predict])

# Scaled
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %% [markdown]
# ### 1.d Data visualization
#
# In order to get a feel for the data distribution, let's do some simple standard visualizations.
#
# We perform dimension reduction using [UMAP](https://umap-learn.readthedocs.io/en/latest/). In its usage, UMAP is similar to [PCA](https://en.wikipedia.org/wiki/Principal_component_analysis) or [t-SNE](https://en.wikipedia.org/wiki/T-SNE), but is much faster.
#
# We see on the graph below that clients that have churned (orange points) aren't in a very definite cluster. This means that _we will_ have trouble making churn predictions.

# %%
from umap import UMAP
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Dimension reduction using the UMAP algorithm
dimreduc = UMAP()
X_2d = dimreduc.fit_transform(X)

sns.scatterplot(X_2d[:,0], X_2d[:,1], hue=y.reshape(-1), markers='x')
# Out:
# /home/haxxor/.conda/envs/deep/lib/python3.7/site-packages/numba/typed_passes.py:293: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../.conda/envs/deep/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))
# /home/haxxor/.conda/envs/deep/lib/python3.7/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 36 separate connected components using meta-embedding (experimental)
#   n_components
# /home/haxxor/.conda/envs/deep/lib/python3.7/site-packages/sklearn/manifold/_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %% [markdown]
# Let's examine some boxplots for clients that churned and clients that didn't. This allows us to explore the features distribution for churning clients and non-churning clients. Because there are many columns, we pick random ones.
#
# We see that there is no clear difference between those two. This _definitely_ means that our machine learning model will have trouble making predictions.

# %%
sns.boxplot(data=X_sampled[y_sampled==1][:,10:30]) 
plt.title('Clients that churned')
plt.show()

sns.boxplot(data=X_sampled[y_sampled==0][:,10:30]) 
plt.title('Clients that stayed')
plt.show()

# %% [markdown]
# ## 2. Picking a prediction model
#
# Using the previously built and cleaned dataset, we build a binary prediction model.

# %%
#Train and test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %% [markdown]
# ### 3.a Baseline : random forest
#
# Random forest is an easy out-of-the box algorithm for classification. We'll use it as a baseline.

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, max_depth=10)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ### 2.b On evaluating the model
#
# How good is the model we trained ? Let's check.
#
# `clf.score()` returns the accuracy of the model. That is, how many times our model was right. Here, it says that about 90% of our predictions are correct.

# %%
clf.score(X_test, y_test)
# Out:
# 0.89756560227632

# %% [markdown]
# But in the dataset, 90% of the clients don't churn. Which means that a model always saying that client will never churn would also get a score of 90% !

# %%
# Proportion of client that don't churn in the dataset : 90% !
# Rougly speaking, a dumb classifier always saying "the client will never churn" would get an accuracy of 90%.
# But would be totally useless.
1-sum(y)/len(y)
# Out:
# 0.9017896667299058

# %% [markdown]
# Business-wise, such a model (which always says a client won't churn) is not useful at all. Another metric, more precise, is needed.
#
# In our case, a more relevant metric is the AUC. The AUC is the area under the ROC curve. Closer it is to 1, the better is our model not only at predicting, but also at **discriminating**. That is, at saying which clients will churn *and* which clients won't churn.

# %%
from sklearn.metrics import roc_auc_score

# With this metric, our previous "dumb" classifier which always predict "the client will never churn"
# would only get a score of 50%. How better is our model ?
preds = clf.predict_proba(X_test)[:,1]
print('ROC AUC score: ', roc_auc_score(y_test, preds)) #more than 50%, which is great ! The model is useful.
# Out:
# ROC AUC score:  0.6831576498419283

# %% [markdown]
# ### 2.c XGBoost
#
# XGBoost is a library of boosted tree models that are highly popular. They are often the ones winning Kaggle competition. They are extremely efficient for binary classification. Let's compare it to random forests.

# %%
from xgboost import XGBClassifier

xgbc = XGBClassifier()
xgbc.fit(X_train, y_train)
print('Accuracy', xgbc.score(X_test, y_test))
preds = xgbc.predict_proba(X_test)[:,1]
print('ROC AUC score: ', roc_auc_score(y_test, preds))
# Out:
# Accuracy 0.9061018020866266
# ROC AUC score:  0.7140403289282002

# %% [markdown]
# The scores are higher, which is great. We decide to stick on this model.
#
# Now, the goal is to optimize this model by picking the best hyperparameters. To do that, we try a lot of random combination of parameters using Random Search. We verify that these parameters aren't just "lucky" by using cross validation. We select our best model given its ROAC AUC score.

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid = {'learning_rate': list(np.linspace(0.1, 0.3, num = 3)),
              'n_estimators': [50, 80, 100, 130, 150],
              'reg_alpha': list(np.linspace(0.0001, 0.01, num = 3)),
              "max_depth": [3, 4, 5]}

xgbc_random = RandomizedSearchCV(estimator=xgbc, n_iter=30, param_distributions = random_grid, 
                          cv = 3, verbose=100, n_jobs = 8, scoring='roc_auc')

xgbc_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# Memmapping (shape=(12650, 521), dtype=float64) to new file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   1 tasks      | elapsed:   13.7s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:   13.9s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   3 tasks      | elapsed:   14.0s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   4 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=8)]: Done   5 tasks      | elapsed:   14.1s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   6 tasks      | elapsed:   24.3s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   7 tasks      | elapsed:   24.4s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   8 tasks      | elapsed:   24.6s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:   24.7s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  10 tasks      | elapsed:   25.1s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  11 tasks      | elapsed:   35.9s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  12 tasks      | elapsed:   36.1s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  13 tasks      | elapsed:   51.6s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  14 tasks      | elapsed:   51.8s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  15 tasks      | elapsed:   53.8s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:   54.0s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  17 tasks      | elapsed:   55.1s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  18 tasks      | elapsed:  1.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  19 tasks      | elapsed:  1.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  20 tasks      | elapsed:  1.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  21 tasks      | elapsed:  1.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  22 tasks      | elapsed:  1.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  23 tasks      | elapsed:  1.5min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  24 tasks      | elapsed:  1.5min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:  1.5min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  26 tasks      | elapsed:  1.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  27 tasks      | elapsed:  1.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  28 tasks      | elapsed:  1.8min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  29 tasks      | elapsed:  1.8min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  30 tasks      | elapsed:  1.8min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  31 tasks      | elapsed:  1.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  32 tasks      | elapsed:  1.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  33 tasks      | elapsed:  1.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:  1.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:  2.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  36 tasks      | elapsed:  2.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  37 tasks      | elapsed:  2.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  38 tasks      | elapsed:  2.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  39 tasks      | elapsed:  2.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  40 tasks      | elapsed:  2.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  41 tasks      | elapsed:  2.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  42 tasks      | elapsed:  2.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  43 tasks      | elapsed:  2.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  44 tasks      | elapsed:  2.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:  2.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  46 tasks      | elapsed:  2.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  47 tasks      | elapsed:  2.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  48 tasks      | elapsed:  2.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  49 tasks      | elapsed:  2.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  50 tasks      | elapsed:  3.0min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  51 tasks      | elapsed:  3.0min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:  3.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  53 tasks      | elapsed:  3.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  54 tasks      | elapsed:  3.2min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  55 tasks      | elapsed:  3.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:  3.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  57 tasks      | elapsed:  3.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  58 tasks      | elapsed:  3.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  59 tasks      | elapsed:  3.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  60 tasks      | elapsed:  3.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  61 tasks      | elapsed:  3.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  62 tasks      | elapsed:  3.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  63 tasks      | elapsed:  3.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  64 tasks      | elapsed:  3.9min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  65 tasks      | elapsed:  4.0min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  66 tasks      | elapsed:  4.0min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  67 tasks      | elapsed:  4.0min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  68 tasks      | elapsed:  4.1min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  69 tasks      | elapsed:  4.3min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  70 tasks      | elapsed:  4.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  71 tasks      | elapsed:  4.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  72 tasks      | elapsed:  4.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  73 tasks      | elapsed:  4.4min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  74 tasks      | elapsed:  4.5min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  75 tasks      | elapsed:  4.6min
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  76 out of  90 | elapsed:  4.7min remaining:   52.0s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  77 out of  90 | elapsed:  4.7min remaining:   47.9s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  78 out of  90 | elapsed:  4.8min remaining:   44.1s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  79 out of  90 | elapsed:  4.8min remaining:   40.4s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  80 out of  90 | elapsed:  4.8min remaining:   36.3s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8433,), dtype=int64).
# Pickling array (shape=(4217,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  81 out of  90 | elapsed:  4.8min remaining:   32.3s
# Memmapping (shape=(12650, 521), dtype=float64) to old file /dev/shm/joblib_memmapping_folder_2323_2802910166/2323-140159695242768-b405c87a140249a98ff65501cd102abf.pkl
# Pickling array (shape=(12650,), dtype=float64).
# Pickling array (shape=(8434,), dtype=int64).
# Pickling array (shape=(4216,), dtype=int64).
# [Parallel(n_jobs=8)]: Done  82 out of  90 | elapsed:  5.0min remaining:   29.4s
# [Parallel(n_jobs=8)]: Done  83 out of  90 | elapsed:  5.1min remaining:   25.8s
# [Parallel(n_jobs=8)]: Done  84 out of  90 | elapsed:  5.2min remaining:   22.3s
# [Parallel(n_jobs=8)]: Done  85 out of  90 | elapsed:  5.3min remaining:   18.6s
# [Parallel(n_jobs=8)]: Done  86 out of  90 | elapsed:  5.3min remaining:   14.8s
# [Parallel(n_jobs=8)]: Done  87 out of  90 | elapsed:  5.3min remaining:   11.0s
# [Parallel(n_jobs=8)]: Done  88 out of  90 | elapsed:  5.4min remaining:    7.4s
# [Parallel(n_jobs=8)]: Done  90 out of  90 | elapsed:  5.5min remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  90 out of  90 | elapsed:  5.5min finished
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=XGBClassifier(base_score=0.5, booster=None,
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints=None,
#                                            learning_rate=0.300000012,
#                                            max_delta_step=0, max_depth=6,
#                                            min_child_weight=1, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n...
#                                            subsample=1, tree_method=None,
#                                            validate_parameters=False,
#                                            verbosity=None),
#                    iid='deprecated', n_iter=30, n_jobs=8,
#                    param_distributions={'learning_rate': [0.1, 0.2, 0.3],
#                                         'max_depth': [3, 4, 5],
#                                         'n_estimators': [50, 80, 100, 130, 150],
#                                         'reg_alpha': [0.0001,
#                                                       0.005050000000000001,
#                                                       0.01]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=100)

# %%
print('Accuracy', xgbc_random.best_estimator_.score(X_test, y_test))
preds = xgbc_random.best_estimator_.predict_proba(X_test)[:,1]
print('ROC AUC score: ', roc_auc_score(y_test, preds))

xgbc_random.best_params_
# Out:
# Accuracy 0.9038887132469174
# ROC AUC score:  0.7201169556312211
# {'reg_alpha': 0.005050000000000001,
#  'n_estimators': 130,
#  'max_depth': 5,
#  'learning_rate': 0.1}

# %% [markdown]
# Now that we've found the best parameters, we train our model on the whole dataset. This fully trained model would then be used for production purposes, for example.

# %%
xgbc_best = XGBClassifier(**xgbc_random.best_params_)
xgbc_best.fit(X, y)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=130, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0,
#               reg_alpha=0.005050000000000001, reg_lambda=1, scale_pos_weight=1,
#               subsample=1, tree_method=None, validate_parameters=False,
#               verbosity=None)

# %% [markdown]
# This ROC score is interesting in order to compare mathematical performance.
#
# **But how this model perform from a business standpoint ?** This is what we'll study next.

# %% [markdown]
# ## 3. Avoiding churn
#
# The xgboost model we built return a value between 0 and 1 associated with the probability of the client churning.
#
# Let's assume that to prevent a client from churning, PowerCo issues a 15% discount on their electricity price. We also assume that this definitively deters the client from churning.
#
# PowerCo doesn't want either to lose a client and is ready to give it a discount. But PowerCo, however, doesn't want to hand out free discounts. Above which churn probability should PowerCo issue its 15% discount ?

# %%
import matplotlib.pyplot as plt

def test_model(y, preds, margins, DISCOUNT_RATE=0.15):
    """Test a model by calculating the margin saved when applying a discount,
    taking into account discounts wrongly applied to non-churning clients. """
    def find_best_p(preds, discount, granularity=200):
        """Optimization function to find the best probability cutoff"""
        probas = np.linspace(0, 1, granularity)
        output_margins = np.zeros(len(probas))
        actual_churners = (y == 1)

        gains = np.sum(margins)
        loss = sum(margins[actual_churners])

        for i, p in enumerate(probas):
            predicted_churners = preds>=p
            prevented_loss = sum(margins[predicted_churners & actual_churners])
            # To make calculations easier, we assume that the discount
            # is operated on the net margin. It could actually be a bit more. 
            discount_loss = sum(margins[predicted_churners])*discount
            output_margins[i] = gains - loss + prevented_loss - discount_loss

        best_profit = max(output_margins)
        best_p_index = list(output_margins).index(best_profit)
        best_p = probas[best_p_index]
        worst_profit = gains - loss
        return probas, output_margins, best_p, best_profit, worst_profit
    
    # Textual and graphical output interpreting the result
    probas, output_margins, best_p, best_profit, worst_profit = find_best_p(preds, DISCOUNT_RATE, 200)
    print('Above a', round(best_p,4), 'predicted probability of churn, we should apply the', DISCOUNT_RATE*100, '% discount to the client.')
    print("By doing so, PowerCo would make {} € more in annual profit ({}% more than without the model.)".format(
                            round(best_profit-worst_profit,2), 
                            round(100*(best_profit-worst_profit)/worst_profit,2)))

    plt.plot(probas, output_margins)
    plt.axvline(x=best_p, color='red')
    plt.show()

# %%
margins = X[:,list(cleaned_df.columns).index('net_margin_ele')]

print('XGBoost model')
preds = xgbc_best.predict_proba(X)[:,1]
test_model(y, preds, margins)
# Out:
# XGBoost model
# Above a 0.1508 predicted probability of churn, we should apply the 15.0 % discount to the client.
# By doing so, PowerCo would make 205608.06 € more in annual profit (6.71% more than without the model.)

# %% [markdown]
# ## Conclusion
#
# The best model, that usesXGBoost, can save PowerCo about 6% in annual profit (probably a bit less), simply by offering 15% discount to clients likely to churn.
